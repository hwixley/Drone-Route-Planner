# %%
import matplotlib.pyplot as plt
import numpy as np
from numpy import loadtxt
strG2Moves = loadtxt("../aqmapsGreedy2OptMoves.txt", dtype="str",delimiter="\n", unpack=False)
strGMoves = loadtxt("../aqmapsGreedyMoves.txt",dtype="str",delimiter="\n",unpack=False)
str2Moves = loadtxt("../aqmaps2OptMoves.txt",dtype="str",delimiter="\n",unpack=False)
dates = loadtxt("../aqmapsDates.txt",dtype="str",delimiter="\n",unpack=False)

# %%
import seaborn as sns
import pandas as pd
x = range(92)

gMoves = np.empty(len(dates))
g2Moves = np.empty(len(dates))
twoMoves = np.empty(len(dates))

for i in range(len(dates)):
    gMoves[i] = int(strGMoves[i])
    g2Moves[i] = int(strG2Moves[i])
    twoMoves[i] = int(str2Moves[i])
    
plt.rcParams["figure.figsize"] = (13,8)
plt.scatter(x,g2Moves[0:92],c="blue",label="Greedy w/ 2-Opt")
plt.plot(x, np.poly1d(np.polyfit(x, g2Moves[0:92], 1))(np.unique(x)),c="blue")

plt.scatter(x,gMoves[0:92],c="red",label="Greedy")
plt.plot(x, np.poly1d(np.polyfit(x, gMoves[0:92], 1))(np.unique(x)),c="red")

plt.scatter(x,twoMoves[0:92],c="green",label="2-Opt")
plt.plot(x, np.poly1d(np.polyfit(x, twoMoves[0:92], 1))(np.unique(x)),c="green")

plt.grid(True)
plt.legend(loc="lower left")
plt.xlabel("Day #",fontsize=16)
plt.ylabel("# Moves",fontsize=16)
plt.xticks(x,range(1,93),rotation=90,fontsize=7)
plt.title("A graph to show route performance of different models for all unique days",fontsize=18)
# Out:
# Text(0.5,1,'A graph to show route performance of different models for all unique days')

# %%
plt.plot(range(len(dates)),g2Moves,c="blue",label="Greedy w/ 2-Opt",lw=1)
plt.plot(range(len(dates)),gMoves,c="red", label="Greedy",lw=1)
plt.plot(range(len(dates)),twoMoves,c="green",label="2-Opt",lw=1)
plt.legend(loc="lower left")
plt.xlabel("Day #",fontsize=16)
plt.ylabel("# Moves",fontsize=16)
plt.title("A graph to show the performance of models for all days in 2020 & 2021",fontsize=18)
# Out:
# Text(0.5,1,'A graph to show the performance of models for all days in 2020 & 2021')
